psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b2/c1/7bf6c464e903ffc4f3f5907c389e5a4199666bf57f6cd6bf46c17912a1f9/psycopg2-2.7.5.tar.gz#sha256=eccf962d41ca46e6326b97c8fe0a6687b58dfc1a5f6540ed071ff1474cea749e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.4.tar.gz (425 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_48c4abaa860d45e5ac8989608358cec4/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_48c4abaa860d45e5ac8989608358cec4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_48c4abaa860d45e5ac8989608358cec4/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-q62aqqoj/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/74/83/51580322ed0e82cba7ad8e0af590b8fb2cf11bd5aaa1ed872661bd36f462/psycopg2-2.7.4.tar.gz#sha256=8bf51191d60f6987482ef0cfe8511bbf4877a5aa7f313d7b488b53189cf26209 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.3.2.tar.gz (425 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_9256f16a20584de8968328a0c669e358/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_9256f16a20584de8968328a0c669e358/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_9256f16a20584de8968328a0c669e358/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0wdjf1e8/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/dd/47/000b405d73ca22980684fd7bd3318690cc03cfa3b2ae1c5b7fff8050b28a/psycopg2-2.7.3.2.tar.gz#sha256=5c3213be557d0468f9df8fe2487eaf2990d9799202c5ff5cb8d394d09fad9b2a (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.3.1.tar.gz (425 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_0c296c45d5d043959bb1da1c5e3b5fad/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_0c296c45d5d043959bb1da1c5e3b5fad/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_0c296c45d5d043959bb1da1c5e3b5fad/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-ep0kydaa/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6b/fb/15c687eda2f925f0ff59373063fdb408471b4284714a7761daaa65c01f15/psycopg2-2.7.3.1.tar.gz#sha256=9b7b16e26448b43cf167f785d8b5345007731ebf153a510e12dae826800caa65 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.3.tar.gz (425 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_8009042308764e84960cea7217294dbe/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_8009042308764e84960cea7217294dbe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_8009042308764e84960cea7217294dbe/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-o7cr3gx5/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/98/99/33ca02c4bc3ed1bd9ceab5614bda2e6d1d31e61ec58345b9feece238c38a/psycopg2-2.7.3.tar.gz#sha256=c9bd49848556d04093909faec017c3675efabf78c2b7f383bf7c43ba18324ac8 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.2.tar.gz (424 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_144d0883aef7463c8e21042f650cc542/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_144d0883aef7463c8e21042f650cc542/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_144d0883aef7463c8e21042f650cc542/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-_ylotlks/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d0/66/61c1b34ea8da8f95d99676e6803ccad83abef3ac90df145b45033696f3d2/psycopg2-2.7.2.tar.gz#sha256=3767f40bb35713ccc75dbcff80bf228a75e080d6b98c78afd5fb9aa84682a9f4 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.1.tar.gz (421 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c8b485f7027743dc8f3a72403f4384e5/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c8b485f7027743dc8f3a72403f4384e5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c8b485f7027743dc8f3a72403f4384e5/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-0_pdo6_g/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f8/e9/5793369ce8a41bf5467623ded8d59a434dfef9c136351aca4e70c2657ba0/psycopg2-2.7.1.tar.gz#sha256=86c9355f5374b008c8479bc00023b295c07d508f7c3b91dbd2e74f8925b1d9c6 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.7.tar.gz (421 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_5681effae2e64eb7bdd7b3413f9928c6/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_5681effae2e64eb7bdd7b3413f9928c6/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_5681effae2e64eb7bdd7b3413f9928c6/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk/psycopg2.egg-info
#     writing /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-nlphkqtk/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
# ...
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_82cf4c4a32c444cf81a474bf2aa23d5c/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_82cf4c4a32c444cf81a474bf2aa23d5c/setup.py", line 247
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/68/0a/459df8dcbcc118ca435e9567abceaab919706908d52139e503f6396c4935/psycopg2-2.3.0.tar.gz#sha256=c17a06b7468debba94fa151d3ad93cd885d9cbe9a751e54ceb87738d5f0478ea (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.2.2.tar.gz (530 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_612a8d8c966f4d2eb928420b0237ec0d/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_612a8d8c966f4d2eb928420b0237ec0d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-a6jdd3ut
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_612a8d8c966f4d2eb928420b0237ec0d/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2
^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/d7/496da11d7c81971870ddd36800419c4f84e8f6208aac5eabedf9f7748729/psycopg2-2.0.11.tar.gz#sha256=e6b4e0e41df97441eff34e00065376414da6488e0d55848a45cd77551dbae434 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.0.10.tar.gz (255 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tinahuang/opt/anaconda3/envs/PythonData/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c965c005d6c14c79a11bc7551574f4fd/setup.py'"'"'; __file__='"'"'/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c965c005d6c14c79a11bc7551574f4fd/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-pip-egg-info-6gasnnlt
#          cwd: /private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c965c005d6c14c79a11bc7551574f4fd/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/10/xt_vfp612vj4w33xltbsplxm0000gn/T/pip-install-ctgv9kg_/psycopg2_c965c005d6c14c79a11bc7551574f4fd/setup.py", line 50, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/79/35c7596bab4456f3610c12ec542a94d51c6781ced587d1d85127210b879b/psycopg2-2.0.10.tar.gz#sha256=e40cc04b43849085725076ae134bfef9e3b087f6dd7c964aeeb930e2f0bc14ab (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement psycopg2 (from versions: 2.0.10, 2.0.11, 2.0.12, 2.0.13, 2.0.14, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.3.2, 2.4, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.4.5, 2.4.6, 2.5, 2.5.1, 2.5.2, 2.5.3, 2.5.4, 2.5.5, 2.6, 2.6.1, 2.6.2, 2.7, 2.7.1, 2.7.2, 2.7.3, 2.7.3.1, 2.7.3.2, 2.7.4, 2.7.5, 2.7.6, 2.7.6.1, 2.7.7, 2.8, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.8.5, 2.8.6)
# ERROR: No matching distribution found for psycopg2

# %%
# Dependencies and Setup
# SQL Alchemy
from sqlalchemy import create_engine

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt

# NumPy
import numpy as np

# %%
# Create Engine and Pass in Postgres Connection
# Setup to Connect to Database 
engine = create_engine('postgres://postgres:password1234@localhost:5432/employee_db')
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b7c8b8b430bd> in <module>
#       1 # Create Engine and Pass in Postgres Connection
#       2 # Setup to Connect to Database
# ----> 3 engine = create_engine('postgres://postgres:password1234@localhost:5432/employee_db')
#       4 conn = engine.connect()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     498     strategy = kwargs.pop("strategy", default_strategy)
#     499     strategy = strategies.strategies[strategy]
# --> 500     return strategy.create(*args, **kwargs)
#     501
#     502
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in dbapi(cls)
#     751     @classmethod
#     752     def dbapi(cls):
# --> 753         import psycopg2
#     754
#     755         return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
